# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu'], axis=1, inplace=True)

# %%
median_lotFrontage = df['LotFrontage'].median()
df['LotFrontage'] = df['LotFrontage'].fillna(median_lotFrontage)

# %%
duplicates = df.duplicated()
duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 1460, dtype: bool

# %%
duplicates_df = df[duplicates]
duplicates_df
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
df.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1460.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    69.863699   10516.828082    NaN
# std      421.610009    42.300571      NaN    22.027677    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    60.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    79.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['SalePrice'], bins=20)
plt.axvline(int(df['SalePrice'].mean()), label='Средняя стоимость', color='green')
plt.axvline(int(df['SalePrice'].median()), label='Медианная стоимость', color='red')
plt.legend()
plt.title('Стоимость объекта')
plt.xlabel('Стоимость')
plt.ylabel('Количество')

# %%
data = df['OverallQual'].value_counts().reset_index()
data.head()
# Out:
#    index  OverallQual
# 0      5          397
# 1      6          374
# 2      7          319
# 3      8          168
# 4      4          116

# %%
# 10 Very Excellent
# 9	Excellent
# 8	Very Good
# 7	Good
# 6	Above Average
# 5	Average
# 4	Below Average
# 3	Fair
# 2	Poor
# 1	Very Poor
plt.figure(figsize=(6, 4))
sns.barplot(x=data['index'], y=data['OverallQual'])
plt.title('Количество объектов в зависимости от материала и отделки')
plt.xlabel('Качество')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
df['GrLivArea'].describe()
# Out:
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['GrLivArea'], bins=20)
plt.axvline(int(df['GrLivArea'].mean()), label='Средняя жилая площадь', color='green')
plt.axvline(int(df['GrLivArea'].median()), label='Медианная жилая площадь', color='red')
plt.legend()
plt.title('Жилая площадь')
plt.xlabel('Жилая площадь')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
df['GarageCars'].unique()
# Out:
# array([2, 3, 1, 0, 4], dtype=int64)

# %%
data = df['GarageCars'].value_counts().reset_index()
plt.figure(figsize=(6, 4))
sns.barplot(x=data['index'], y=data['GarageCars'])
plt.title('Количество объектов в зависимости от размера гаража')
plt.xlabel('Размер гаража')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %%
h = sns.jointplot(x=df['SalePrice'], y=df['GrLivArea'], kind='reg')
h.set_axis_labels('Стоимость', 'Жилая площадь')
h.fig.suptitle('Взаимосвязь стоимости и жилой площади')
# Out:
# Text(0.5, 0.98, 'Взаимосвязь стоимости и жилой площади')

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['OverallQual'], y=df['SalePrice'], showfliers=False)
plt.xlabel('Качество')
plt.ylabel('Стоимость')
plt.title('Взаимосвязь стоимости и качества')
# Out:
# Text(0.5, 1.0, 'Взаимосвязь стоимости и качества')

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['GarageCars'], y=df['SalePrice'], showfliers=False)
plt.xlabel('Размер гаража')
plt.ylabel('Стоимость')
plt.title('Взаимосвязь стоимости и размера гаража')
# Out:
# Text(0.5, 1.0, 'Взаимосвязь стоимости и размера гаража')

# %%
df['Street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
df = pd.get_dummies(df, columns=['Street'], prefix='Street')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0   1          60       RL         65.0     8450      Reg         Lvl
# 1   2          20       RL         80.0     9600      Reg         Lvl
# 2   3          60       RL         68.0    11250      IR1         Lvl
# 3   4          70       RL         60.0     9550      IR1         Lvl
# 4   5          60       RL         84.0    14260      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# ...

# %%
df['Street_Pave'].unique()
# Out:
# array([1, 0], dtype=uint8)

# %%
le = LabelEncoder()
df['Neighborhood_Encoded'] = le.fit_transform(df['Neighborhood'])
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0   1          60       RL         65.0     8450      Reg         Lvl
# 1   2          20       RL         80.0     9600      Reg         Lvl
# 2   3          60       RL         68.0    11250      IR1         Lvl
# 3   4          70       RL         60.0     9550      IR1         Lvl
# 4   5          60       RL         84.0    14260      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# ...

# %%
df['Neighborhood_Encoded'].unique()
# Out:
# array([ 5, 24,  6, 15, 11, 21, 14, 17,  3, 19, 16, 12, 20,  9, 10,  7, 23,
#         8, 22,  4, 13,  0,  2, 18,  1])

# %%
df.to_csv('cleaned_house_prices.csv', index= False )
